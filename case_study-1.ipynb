# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
data_income=pd.read_csv('income.csv')
data=data_income.copy()

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31978 entries, 0 to 31977
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            31978 non-null  int64
#  1   JobType        31978 non-null  object
#  2   EdType         31978 non-null  object
#  3   maritalstatus  31978 non-null  object
#  4   occupation     31978 non-null  object
#  5   relationship   31978 non-null  object
#  6   race           31978 non-null  object
#  7   gender         31978 non-null  object
#  8   capitalgain    31978 non-null  int64
#  9   capitalloss    31978 non-null  int64
#  10  hoursperweek   31978 non-null  int64
#  11  nativecountry  31978 non-null  object
#  12  SalStat        31978 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 3.2+ MB
# None

# %%
data.isnull().sum()
# Out:
# age              0
# JobType          0
# EdType           0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# gender           0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# nativecountry    0
# SalStat          0
# dtype: int64

# %%
summary=data.describe()
print(summary)
# Out:
#                 age   capitalgain   capitalloss  hoursperweek
# count  31978.000000  31978.000000  31978.000000  31978.000000
# mean      38.579023   1064.360623     86.739352     40.417850
# std       13.662085   7298.596271    401.594301     12.345285
# min       17.000000      0.000000      0.000000      1.000000
# 25%       28.000000      0.000000      0.000000     40.000000
# 50%       37.000000      0.000000      0.000000     40.000000
# 75%       48.000000      0.000000      0.000000     45.000000
# max       90.000000  99999.000000   4356.000000     99.000000

# %%
summary_cate=data.describe(include='O')
print(summary_cate)
# Out:
#          JobType    EdType        maritalstatus       occupation relationship  \
# count      31978     31978                31978            31978        31978
# unique         9        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22286     10368                14692             4038        12947
#
#           race gender   nativecountry                        SalStat
# count    31978  31978           31978                          31978
# unique       5      2              41                              2
# top      White   Male   United-States   less than or equal to 50,000
# freq     27430  21370           29170                          24283

# %%
data['JobType'].value_counts()
data['occupation'].value_counts()
# Out:
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  ?                    1816
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
print(np.unique(data['JobType']))
print(np.unique(data['occupation']))
# Out:
# [' ?' ' Federal-gov' ' Local-gov' ' Never-worked' ' Private'
#  ' Self-emp-inc' ' Self-emp-not-inc' ' State-gov' ' Without-pay']
# [' ?' ' Adm-clerical' ' Armed-Forces' ' Craft-repair' ' Exec-managerial'
#  ' Farming-fishing' ' Handlers-cleaners' ' Machine-op-inspct'
#  ' Other-service' ' Priv-house-serv' ' Prof-specialty' ' Protective-serv'
#  ' Sales' ' Tech-support' ' Transport-moving']

# %%
data=pd.read_csv('income.csv',na_values=[" ?"])
data.head(50)
# Out:
#     age            JobType         EdType           maritalstatus  \
# 0    45            Private        HS-grad                Divorced
# 1    24        Federal-gov        HS-grad           Never-married
# 2    44            Private   Some-college      Married-civ-spouse
# 3    27            Private            9th           Never-married
# 4    20            Private   Some-college           Never-married
# 5    44            Private        HS-grad                 Widowed
# 6    51            Private        HS-grad      Married-civ-spouse
# 7    20            Private        HS-grad      Married-civ-spouse
# 8    17                NaN           11th           Never-married
# 9    19            Private        HS-grad           Never-married
# 10   45       Self-emp-inc   Some-college      Married-civ-spouse
# 11   60            Private        HS-grad      Married-civ-spouse
# 12   44   Self-emp-not-inc        HS-grad      Married-civ-spouse
# 13   40            Private      Assoc-voc      Married-civ-spouse
# 14   30            Private        HS-grad      Married-civ-spouse
# 15   38            Private   Some-college      Married-civ-spouse
# 16   23            Private        HS-grad      Married-civ-spouse
# 17   32                NaN   Some-college      Married-civ-spouse
# 18   44            Private     Assoc-acdm           Never-married
# 19   54          Local-gov        HS-grad      Married-civ-spouse
# 20   32            Private      Bachelors      Married-civ-spouse
# 21   50            Private        1st-4th   Married-spouse-absent
# 22   24            Private      Bachelors           Never-married
# 23   37            Private        HS-grad      Married-civ-spouse
# 24   52            Private        HS-grad                Divorced
# 25   38            Private   Some-college      Married-civ-spouse
# 26   49            Private        Masters      Married-civ-spouse
# 27   30            Private      Bachelors      Married-civ-spouse
# 28   60            Private   Some-college           Never-married
# 29   22                NaN   Some-college           Never-married
# 30   35            Private        HS-grad           Never-married
# 31   30            Private        HS-grad           Never-married
# 32   67            Private      Assoc-voc                Divorced
# 33   46            Private      Bachelors           Never-married
# 34   17            Private            9th           Never-married
# 35   22            Private   Some-college           Never-married
# 36   27            Private           10th           Never-married
# 37   23            Private        HS-grad           Never-married
# 38   33            Private     Assoc-acdm      Married-civ-spouse
# 39   43   Self-emp-not-inc   Some-college      Married-civ-spouse
# 40   28          State-gov      Bachelors           Never-married
# 41   41            Private        HS-grad   Married-spouse-absent
# 42   52                NaN           12th           Never-married
# 43   25            Private   Some-college   Married-spouse-absent
# 44   63                NaN        1st-4th      Married-civ-spouse
# 45   59          Local-gov        HS-grad      Married-civ-spouse
# 46   45          Local-gov      Bachelors                Divorced
# 47   38            Private      Bachelors      Married-civ-spouse
# 48   40            Private        HS-grad           Never-married
# 49   46        Federal-gov        HS-grad                Divorced
#
#             occupation     relationship                 race   gender  \
# 0         Adm-clerical    Not-in-family                White   Female
# 1         Armed-Forces        Own-child                White     Male
# 2       Prof-specialty          Husband                White     Male
# 3         Craft-repair   Other-relative                White     Male
# 4                Sales    Not-in-family                White     Male
# 5      Exec-managerial        Unmarried                Black   Female
# 6         Craft-repair          Husband   Amer-Indian-Eskimo     Male
# 7    Machine-op-inspct          Husband                White     Male
# 8                  NaN        Own-child                White   Female
# 9    Machine-op-inspct        Own-child                Black   Female
# 10        Craft-repair          Husband                White     Male
# 11        Craft-repair          Husband                White     Male
# 12               Sales             Wife                White   Female
# 13   Machine-op-inspct          Husband   Asian-Pac-Islander     Male
# 14     Exec-managerial             Wife                White   Female
# 15    Transport-moving          Husband                Black     Male
# 16    Transport-moving          Husband                White     Male
# 17                 NaN          Husband                White     Male
# 18     Farming-fishing        Own-child                White     Male
# 19    Transport-moving          Husband                Black     Male
# 20      Prof-specialty          Husband                White     Male
# 21        Craft-repair        Unmarried                White     Male
# 22        Tech-support    Not-in-family                White   Female
# 23        Adm-clerical             Wife                White   Female
# 24    Transport-moving        Unmarried                White     Male
# 25    Transport-moving          Husband                White     Male
# 26     Exec-managerial          Husband                White     Male
# 27        Tech-support             Wife                White   Female
# 28      Prof-specialty        Unmarried                White     Male
# 29                 NaN        Own-child                White     Male
# 30        Craft-repair    Not-in-family                White     Male
# 31    Transport-moving    Not-in-family                White     Male
# 32       Other-service    Not-in-family                White   Female
# 33        Craft-repair    Not-in-family                White   Female
# 34       Other-service    Not-in-family                White     Male
# 35   Handlers-cleaners        Own-child                White     Male
# 36       Other-service    Not-in-family                White     Male
# 37       Other-service        Unmarried                White   Female
# 38        Craft-repair          Husband                White     Male
# 39        Craft-repair          Husband                White     Male
# 40      Prof-specialty    Not-in-family                White     Male
# 41        Craft-repair        Unmarried                White   Female
# 42                 NaN   Other-relative                Black     Male
# 43        Adm-clerical        Own-child                Black   Female
# 44                 NaN          Husband                White     Male
# 45    Transport-moving          Husband                White     Male
# 46      Prof-specialty        Unmarried                White   Female
# 47               Sales          Husband                White     Male
# 48       Other-service    Not-in-family                White   Female
# 49        Adm-clerical    Not-in-family                White     Male
#
#     capitalgain  capitalloss  hoursperweek   nativecountry  \
# 0             0            0            28   United-States
# 1             0            0            40   United-States
# 2             0            0            40   United-States
# 3             0            0            40          Mexico
# 4             0            0            35   United-States
# 5             0            0            40   United-States
# 6             0            0            40   United-States
# 7             0            0            40   United-States
# 8             0            0             5   United-States
# 9             0            0            40   United-States
# 10            0            0            55   United-States
# 11            0            0            40   United-States
# 12            0            0            40   United-States
# 13            0            0            40   United-States
# 14            0            0            40   United-States
# 15            0            0            50   United-States
# 16            0            0            60   United-States
# 17            0            0            40   United-States
# 18            0            0            40   United-States
# 19            0            0            40   United-States
# 20            0            0            50   United-States
# 21            0            0            40   United-States
# 22            0            0            20   United-States
# 23            0            0            60   United-States
# 24            0            0            40   United-States
# 25            0            0            40   United-States
# 26            0         1977            45   United-States
# 27            0            0            16   United-States
# 28            0            0            40   United-States
# 29            0            0            40   United-States
# 30            0            0            40   United-States
# 31            0            0            60   United-States
# 32            0            0            24   United-States
# 33            0            0            40   United-States
# 34            0            0             6   United-States
# 35            0            0            30   United-States
# 36            0            0            40   United-States
# 37            0            0            35   United-States
# 38            0            0            45        Portugal
# 39            0            0            20   United-States
# 40            0            0            20   United-States
# 41            0            0            40   United-States
# 42          594            0            40   United-States
# 43            0            0            20   United-States
# 44            0            0            35   United-States
# 45            0            0            45   United-States
# 46            0            0            40   United-States
# 47        15024            0            60   United-States
# 48            0            0            35   United-States
# 49            0            0            40   United-States
#
#                           SalStat
# 0    less than or equal to 50,000
# 1    less than or equal to 50,000
# 2             greater than 50,000
# 3    less than or equal to 50,000
# 4    less than or equal to 50,000
# 5    less than or equal to 50,000
# 6    less than or equal to 50,000
# 7    less than or equal to 50,000
# 8    less than or equal to 50,000
# 9    less than or equal to 50,000
# 10            greater than 50,000
# 11            greater than 50,000
# 12            greater than 50,000
# 13            greater than 50,000
# 14   less than or equal to 50,000
# 15   less than or equal to 50,000
# 16   less than or equal to 50,000
# 17   less than or equal to 50,000
# 18   less than or equal to 50,000
# 19   less than or equal to 50,000
# 20   less than or equal to 50,000
# 21   less than or equal to 50,000
# 22   less than or equal to 50,000
# 23   less than or equal to 50,000
# 24   less than or equal to 50,000
# 25   less than or equal to 50,000
# 26            greater than 50,000
# 27            greater than 50,000
# 28            greater than 50,000
# 29   less than or equal to 50,000
# 30   less than or equal to 50,000
# 31   less than or equal to 50,000
# 32   less than or equal to 50,000
# 33   less than or equal to 50,000
# 34   less than or equal to 50,000
# 35   less than or equal to 50,000
# 36   less than or equal to 50,000
# 37   less than or equal to 50,000
# 38   less than or equal to 50,000
# 39   less than or equal to 50,000
# 40   less than or equal to 50,000
# 41   less than or equal to 50,000
# 42   less than or equal to 50,000
# 43   less than or equal to 50,000
# 44   less than or equal to 50,000
# 45   less than or equal to 50,000
# 46   less than or equal to 50,000
# 47            greater than 50,000
# 48   less than or equal to 50,000
# 49   less than or equal to 50,000

# %%
data.isnull().sum()
# Out:
# age                 0
# JobType          1809
# EdType              0
# maritalstatus       0
# occupation       1816
# relationship        0
# race                0
# gender              0
# capitalgain         0
# capitalloss         0
# hoursperweek        0
# nativecountry       0
# SalStat             0
# dtype: int64

# %%
missing=data[data.isnull().any(axis=1)]

# %%
missing.head(50)
# Out:
#      age JobType         EdType           maritalstatus occupation  \
# 8     17     NaN           11th           Never-married        NaN
# 17    32     NaN   Some-college      Married-civ-spouse        NaN
# 29    22     NaN   Some-college           Never-married        NaN
# 42    52     NaN           12th           Never-married        NaN
# 44    63     NaN        1st-4th      Married-civ-spouse        NaN
# 57    72     NaN        HS-grad      Married-civ-spouse        NaN
# 69    53     NaN        5th-6th                 Widowed        NaN
# 73    57     NaN      Assoc-voc                 Widowed        NaN
# 75    20     NaN   Some-college           Never-married        NaN
# 76    21     NaN   Some-college           Never-married        NaN
# 97    34     NaN        HS-grad           Never-married        NaN
# 133   18     NaN           12th           Never-married        NaN
# 137   65     NaN   Some-college      Married-civ-spouse        NaN
# 147   42     NaN        HS-grad      Married-civ-spouse        NaN
# 148   55     NaN        HS-grad      Married-civ-spouse        NaN
# 153   23     NaN   Some-college           Never-married        NaN
# 205   58     NaN        HS-grad      Married-civ-spouse        NaN
# 213   70     NaN            9th                 Widowed        NaN
# 225   20     NaN           11th   Married-spouse-absent        NaN
# 228   17     NaN           11th           Never-married        NaN
# 243   66     NaN        7th-8th           Never-married        NaN
# 252   25     NaN     Assoc-acdm           Never-married        NaN
# 288   45     NaN   Some-college      Married-civ-spouse        NaN
# 340   59     NaN        HS-grad      Married-civ-spouse        NaN
# 341   21     NaN        HS-grad           Never-married        NaN
# 344   18     NaN   Some-college           Never-married        NaN
# 358   50     NaN        Masters   Married-spouse-absent        NaN
# 363   22     NaN   Some-college           Never-married        NaN
# 382   42     NaN           11th      Married-civ-spouse        NaN
# 386   72     NaN           11th                 Widowed        NaN
# 437   63     NaN   Some-college      Married-civ-spouse        NaN
# 441   48     NaN   Some-college                Divorced        NaN
# 454   27     NaN     Assoc-acdm      Married-civ-spouse        NaN
# 475   64     NaN        HS-grad      Married-civ-spouse        NaN
# 482   19     NaN   Some-college           Never-married        NaN
# 519   36     NaN      Assoc-voc                 Widowed        NaN
# 532   23     NaN        HS-grad           Never-married        NaN
# 569   19     NaN        HS-grad           Never-married        NaN
# 583   76     NaN        7th-8th                 Widowed        NaN
# 584   19     NaN        HS-grad           Never-married        NaN
# 587   34     NaN           11th      Married-civ-spouse        NaN
# 594   64     NaN     Assoc-acdm           Never-married        NaN
# 645   19     NaN        HS-grad           Never-married        NaN
# 648   68     NaN        7th-8th      Married-civ-spouse        NaN
# 678   34     NaN        HS-grad                Divorced        NaN
# 681   42     NaN   Some-college                Divorced        NaN
# 712   22     NaN   Some-college           Never-married        NaN
# 720   58     NaN   Some-college      Married-civ-spouse        NaN
# 725   50     NaN        HS-grad      Married-civ-spouse        NaN
# 730   51     NaN        Masters      Married-civ-spouse        NaN
#
#         relationship                 race   gender  capitalgain  capitalloss  \
# 8          Own-child                White   Female            0            0
# 17           Husband                White     Male            0            0
# 29         Own-child                White     Male            0            0
# 42    Other-relative                Black     Male          594            0
# 44           Husband                White     Male            0            0
# 57           Husband                White     Male            0            0
# 69         Unmarried                Black   Female            0            0
# 73         Unmarried                White   Female            0            0
# 75         Own-child                White     Male            0            0
# 76         Unmarried                White   Female            0            0
# 97         Unmarried                Black   Female            0            0
# 133        Own-child                White     Male            0            0
# 137          Husband                White     Male            0            0
# 147          Husband                White     Male            0            0
# 148             Wife   Asian-Pac-Islander   Female            0            0
# 153        Unmarried   Amer-Indian-Eskimo   Female            0            0
# 205          Husband                White     Male            0            0
# 213        Unmarried                White   Female         1111            0
# 225        Own-child   Asian-Pac-Islander   Female            0         1762
# 228        Own-child                White   Female            0            0
# 243    Not-in-family                White     Male            0            0
# 252   Other-relative                White     Male            0            0
# 288             Wife                Black   Female            0            0
# 340          Husband                White     Male            0            0
# 341    Not-in-family                White   Female         1055            0
# 344        Own-child                White     Male            0            0
# 358   Other-relative                White     Male            0            0
# 363        Own-child                Black     Male            0            0
# 382          Husband                White     Male            0            0
# 386    Not-in-family                White   Female            0            0
# 437          Husband                White     Male            0            0
# 441        Unmarried                Black   Female            0            0
# 454        Own-child   Amer-Indian-Eskimo     Male            0            0
# 475          Husband                White     Male            0            0
# 482        Own-child                White   Female            0            0
# 519    Not-in-family                White   Female            0            0
# 532        Unmarried                Black   Female            0            0
# 569        Own-child                White     Male            0            0
# 583    Not-in-family                White     Male            0            0
# 584        Unmarried                White     Male            0         2001
# 587             Wife                White   Female            0            0
# 594    Not-in-family                White   Female            0            0
# 645        Own-child                White   Female            0            0
# 648          Husband                White     Male            0            0
# 678    Not-in-family                White   Female            0            0
# 681        Unmarried                White     Male            0            0
# 712        Own-child                White   Female            0            0
# 720          Husband                White     Male            0            0
# 725          Husband                White     Male            0            0
# 730          Husband                White     Male            0            0
#
#      hoursperweek   nativecountry                        SalStat
# 8               5   United-States   less than or equal to 50,000
# 17             40   United-States   less than or equal to 50,000
# 29             40   United-States   less than or equal to 50,000
# 42             40   United-States   less than or equal to 50,000
# 44             35   United-States   less than or equal to 50,000
# 57             20   United-States   less than or equal to 50,000
# 69             30   United-States   less than or equal to 50,000
# 73             38   United-States   less than or equal to 50,000
# 75             24   United-States   less than or equal to 50,000
# 76             35   United-States   less than or equal to 50,000
# 97             40   United-States   less than or equal to 50,000
# 133            25   United-States   less than or equal to 50,000
# 137            30   United-States            greater than 50,000
# 147            40   United-States   less than or equal to 50,000
# 148            40   United-States   less than or equal to 50,000
# 153            25   United-States   less than or equal to 50,000
# 205            50   United-States   less than or equal to 50,000
# 213            15   United-States   less than or equal to 50,000
# 225            40           South   less than or equal to 50,000
# 228            20   United-States   less than or equal to 50,000
# 243             4   United-States   less than or equal to 50,000
# 252            45   United-States   less than or equal to 50,000
# 288            40   United-States   less than or equal to 50,000
# 340            16   United-States   less than or equal to 50,000
# 341            40   United-States   less than or equal to 50,000
# 344            33   United-States   less than or equal to 50,000
# 358            40   United-States   less than or equal to 50,000
# 363            40   United-States   less than or equal to 50,000
# 382            15   United-States   less than or equal to 50,000
# 386            24   United-States   less than or equal to 50,000
# 437            15   United-States   less than or equal to 50,000
# 441            30   United-States   less than or equal to 50,000
# 454            40   United-States   less than or equal to 50,000
# 475             5   United-States   less than or equal to 50,000
# 482            10   United-States   less than or equal to 50,000
# 519            20   United-States   less than or equal to 50,000
# 532            40   United-States   less than or equal to 50,000
# 569            30   United-States   less than or equal to 50,000
# 583             2   United-States   less than or equal to 50,000
# 584            40   United-States   less than or equal to 50,000
# 587             8   United-States   less than or equal to 50,000
# 594            20   United-States   less than or equal to 50,000
# 645            40   United-States   less than or equal to 50,000
# 648             8   United-States   less than or equal to 50,000
# 678            40   United-States   less than or equal to 50,000
# 681            40   United-States   less than or equal to 50,000
# 712             8   United-States   less than or equal to 50,000
# 720            40   United-States            greater than 50,000
# 725            40   United-States            greater than 50,000
# 730            40   United-States   less than or equal to 50,000

# %%
data2=data.dropna(axis=0)

# %%
correlation=data2.corr()

# %%
print(correlation)
# Out:
#                    age  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.080154     0.060165      0.101599
# capitalgain   0.080154     1.000000    -0.032229      0.080432
# capitalloss   0.060165    -0.032229     1.000000      0.052417
# hoursperweek  0.101599     0.080432     0.052417      1.000000

# %%
data2.columns
# Out:
# Index(['age', 'JobType', 'EdType', 'maritalstatus', 'occupation',
#        'relationship', 'race', 'gender', 'capitalgain', 'capitalloss',
#        'hoursperweek', 'nativecountry', 'SalStat'],
#       dtype='object')

# %%
gender=pd.crosstab(index=data2['gender'],columns='count',normalize=True)
print(gender)
# Out:
# col_0       count
# gender
#  Female  0.324315
#  Male    0.675685

# %%
gender_salstat=pd.crosstab(index=data2['gender'],columns=data2['SalStat']
                         ,margins=True,normalize='index')
print(gender_salstat)
# Out:
# SalStat   greater than 50,000   less than or equal to 50,000
# gender
#  Female              0.113678                       0.886322
#  Male                0.313837                       0.686163
# All                  0.248922                       0.751078

# %%
Salstat=sns.countplot(data2['SalStat'])

# %%
sns.distplot(data2['age'],bins=10,kde=False)

# %%
sns.boxplot('SalStat','age',data=data2)
data2.groupby('SalStat')['age'].median()
# Out:
# SalStat
#  greater than 50,000             43
#  less than or equal to 50,000    34
# Name: age, dtype: int64

# %%
job_salstat=pd.crosstab(index=data2['JobType'],columns=data2['SalStat']
                         ,margins=True,normalize='index')
print(job_salstat)
# Out:
# SalStat             greater than 50,000   less than or equal to 50,000
# JobType
#  Federal-gov                   0.387063                       0.612937
#  Local-gov                     0.294630                       0.705370
#  Private                       0.218792                       0.781208
#  Self-emp-inc                  0.558659                       0.441341
#  Self-emp-not-inc              0.285714                       0.714286
#  State-gov                     0.268960                       0.731040
#  Without-pay                   0.000000                       1.000000
# All                            0.248922                       0.751078

# %%
Salstat=sns.countplot(x=data2['JobType'],data=data2,hue=data2['SalStat'])
Salstat.set_xticklabels(Salstat.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, ' Private'),
#  Text(0, 0, ' Federal-gov'),
#  Text(0, 0, ' Self-emp-inc'),
#  Text(0, 0, ' Self-emp-not-inc'),
#  Text(0, 0, ' Local-gov'),
#  Text(0, 0, ' State-gov'),
#  Text(0, 0, ' Without-pay')]

# %%
edu_salstat=pd.crosstab(index=data2['EdType'],columns=data2['SalStat']
                         ,margins=True,normalize='index')
print(edu_salstat)
# Out:
# SalStat         greater than 50,000   less than or equal to 50,000
# EdType
#  10th                      0.071951                       0.928049
#  11th                      0.056298                       0.943702
#  12th                      0.076923                       0.923077
#  1st-4th                   0.039735                       0.960265
#  5th-6th                   0.041667                       0.958333
#  7th-8th                   0.062837                       0.937163
#  9th                       0.054945                       0.945055
#  Assoc-acdm                0.253968                       0.746032
#  Assoc-voc                 0.263198                       0.736802
#  Bachelors                 0.421491                       0.578509
#  Doctorate                 0.746667                       0.253333
#  HS-grad                   0.164329                       0.835671
#  Masters                   0.564229                       0.435771
#  Preschool                 0.000000                       1.000000
#  Prof-school               0.749077                       0.250923
#  Some-college              0.200060                       0.799940
# All                        0.248922                       0.751078

# %%
ed=sns.countplot(x=data2['EdType'],data=data2,hue=data2['SalStat'])
ed.set_xticklabels(ed.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, ' HS-grad'),
#  Text(0, 0, ' Some-college'),
#  Text(0, 0, ' 9th'),
#  Text(0, 0, ' Assoc-voc'),
#  Text(0, 0, ' Assoc-acdm'),
#  Text(0, 0, ' Bachelors'),
#  Text(0, 0, ' 1st-4th'),
#  Text(0, 0, ' Masters'),
#  Text(0, 0, ' 10th'),
#  Text(0, 0, ' 5th-6th'),
#  Text(0, 0, ' 11th'),
#  Text(0, 0, ' Prof-school'),
#  Text(0, 0, ' 12th'),
#  Text(0, 0, ' Doctorate'),
#  Text(0, 0, ' 7th-8th'),
#  Text(0, 0, ' Preschool')]

# %%
occ_salstat=pd.crosstab(index=data2['occupation'],columns=data2['SalStat']
                         ,margins=True,normalize='index')
print(occ_salstat)
# Out:
# SalStat              greater than 50,000   less than or equal to 50,000
# occupation
#  Adm-clerical                   0.133835                       0.866165
#  Armed-Forces                   0.111111                       0.888889
#  Craft-repair                   0.225310                       0.774690
#  Exec-managerial                0.485220                       0.514780
#  Farming-fishing                0.116279                       0.883721
#  Handlers-cleaners              0.061481                       0.938519
#  Machine-op-inspct              0.124619                       0.875381
#  Other-service                  0.041096                       0.958904
#  Priv-house-serv                0.006993                       0.993007
#  Prof-specialty                 0.448489                       0.551511
#  Protective-serv                0.326087                       0.673913
#  Sales                          0.270647                       0.729353
#  Tech-support                   0.304825                       0.695175
#  Transport-moving               0.202926                       0.797074
# All                             0.248922                       0.751078

# %%
occ=sns.countplot(x=data2['occupation'],data=data2,hue=data2['SalStat'])
occ.set_xticklabels(occ.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, ' Adm-clerical'),
#  Text(0, 0, ' Armed-Forces'),
#  Text(0, 0, ' Prof-specialty'),
#  Text(0, 0, ' Craft-repair'),
#  Text(0, 0, ' Sales'),
#  Text(0, 0, ' Exec-managerial'),
#  Text(0, 0, ' Machine-op-inspct'),
#  Text(0, 0, ' Transport-moving'),
#  Text(0, 0, ' Farming-fishing'),
#  Text(0, 0, ' Tech-support'),
#  Text(0, 0, ' Other-service'),
#  Text(0, 0, ' Handlers-cleaners'),
#  Text(0, 0, ' Protective-serv'),
#  Text(0, 0, ' Priv-house-serv')]

# %%
sns.distplot(data2['capitalgain'],bins=10,kde=False)

# %%
sns.distplot(data2['capitalloss'],bins=10,kde=False)

# %%
hr_salstat=pd.crosstab(index=data2['hoursperweek'],columns=data2['SalStat']
                         ,margins=True,normalize='index')
print(occ_salstat)
# Out:
# SalStat              greater than 50,000   less than or equal to 50,000
# occupation
#  Adm-clerical                   0.133835                       0.866165
#  Armed-Forces                   0.111111                       0.888889
#  Craft-repair                   0.225310                       0.774690
#  Exec-managerial                0.485220                       0.514780
#  Farming-fishing                0.116279                       0.883721
#  Handlers-cleaners              0.061481                       0.938519
#  Machine-op-inspct              0.124619                       0.875381
#  Other-service                  0.041096                       0.958904
#  Priv-house-serv                0.006993                       0.993007
#  Prof-specialty                 0.448489                       0.551511
#  Protective-serv                0.326087                       0.673913
#  Sales                          0.270647                       0.729353
#  Tech-support                   0.304825                       0.695175
#  Transport-moving               0.202926                       0.797074
# All                             0.248922                       0.751078

# %%
sns.boxplot('SalStat','hoursperweek',data=data2)
data2.groupby('SalStat')['hoursperweek'].median()
# Out:
# SalStat
#  greater than 50,000             40
#  less than or equal to 50,000    40
# Name: hoursperweek, dtype: int64
